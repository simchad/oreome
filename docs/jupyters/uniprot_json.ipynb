# %% [markdown]
# ### Does Streamdata contain Gene Symbol?

# %%
# # My_package 위치를 sys 환경변수에 저장해 둬서, os.chdir 안해도 됨.
# import sys
# sys.path.append('c:/Users/simhc/Documents/Github/proteome-tool')
# sys.path

# For test
import os
from proteometool.api_request import requests_uniprot

print(requests_uniprot.__doc__)
# Out:
# api_request.requests_uniprot
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# This module contains function that mainly using with api_uniprot.py
#
# Contains
# --------
#
# ::
#  _execute_id_mapping            --- Execute id-mapping job
#  parser_id_mapping              --- Parsing .json result
#
# See Also
# --------

# %%
# Recommended or Submission Name 불러오기. ProteinDecription 없으면 Deleted.
import json
import os
import pandas as pd


with open('C:/Users/simhc/Downloads/idmapping_2024_10_14.json', 'r') as f:
    json_data = json.load(f)

# %%
# Recommended or Submission Name 불러오기. ProteinDecription 없으면 Deleted.
import json
import os
import pandas as pd


with open('C:/Users/simhc/Downloads/idmapping_2024_10_28.json', 'r') as f:
    json_data = json.load(f)

# Number of entries (from)
num_sublist = json_data['results'].__len__()

category_name = []
pr_names = []
gg_names = []
entry_from = []

# Parsing
for n_try in range(num_sublist):
    data_dict = json_data["results"][n_try]
    name_dict = data_dict["to"]
    phrase = "Protein Name Joined..."

    print('Processing... %d : %s'%(n_try, data_dict["from"]))

    # Protein Names
    if name_dict.get("proteinDescription") == None:
        entry_from.append(data_dict["from"])
        category_name.append("Deleted")
        pr_names.append('Deleted')
        #print(phrase)
    else:
        try:
            pr_name = name_dict['proteinDescription']['recommendedName']['fullName']['value']
            entry_from.append(data_dict["from"])
            category_name.append('recommendedName')
            pr_names.append(pr_name)
            #print(phrase)
        except:
            pr_name =name_dict['proteinDescription']['submissionNames'][0]['fullName']['value']
            entry_from.append(data_dict["from"])
            category_name.append('submissionNames')
            pr_names.append(pr_name)
            #print(phrase)

    # Gene Names
    if name_dict.get("genes") == None:
        gg_names.append('-')
        #print(phrase)
    else:
        gg_name = name_dict['genes'][0]['geneName']['value']
        gg_names.append(gg_name)
        
    # one or more synonym genes
    # else:
    #     try:
    #         gg_name = name_dict['proteinDescription']['recommendedName']['fullName']['value']
    #         entry_from.append(data_dict["from"])
    #         category_name.append('recommendedName')
    #         gg_names.append(gg_name)
    #         #print(phrase)
    #     except:
    #         pr_name =name_dict['proteinDescription']['submissionNames'][0]['fullName']['value']
    #         entry_from.append(data_dict["from"])
    #         category_name.append('submissionNames')
    #         pr_names.append(pr_name)
    #         #print(phrase)

df_protname = pd.DataFrame({'From': entry_from,
                            'Category': category_name,
                            'Protein Name': pr_names,
                            'Gene Name': gg_names
                            })

df_protname.to_csv(path_or_buf='C:/Users/simhc/Downloads/IDMapped_20241022.CSV', index=None, encoding='utf-8')
# Out:
# Processing... 0 : A0A024RBG1
# Processing... 1 : A0A075B6I0
# Processing... 2 : A0A075B6I9
# Processing... 3 : A0A075B6J9
# Processing... 4 : A0A075B6K4
# Processing... 5 : A0A075B6K5
# Processing... 6 : A0A075B6P5
# Processing... 7 : A0A075B6R2
# Processing... 8 : A0A075B6R9
# Processing... 9 : A0A075B6S5
# Processing... 10 : A0A075B7B8
# Processing... 11 : A0A075B7D0
# Processing... 12 : A0A075B7D8
# Processing... 13 : A0A075B7E8
# Processing... 14 : A0A087WSY4
# Processing... 15 : A0A087WSY6
# Processing... 16 : A0A087WSZ0
# Processing... 17 : A0A087WW87
# Processing... 18 : A0A096LP01
# Processing... 19 : A0A0A0MRZ9
# Processing... 20 : A0A0A0MS15
# Processing... 21 : A0A0A0MT36
# Processing... 22 : A0A0B4J1U7
# Processing... 23 : A0A0B4J1V0
# Processing... 24 : A0A0B4J1V2
# Processing... 25 : A0A0B4J1V6
# Processing... 26 : A0A0B4J1X5
# Processing... 27 : A0A0B4J1Y8
# Processing... 28 : A0A0B4J1Y9
# Processing... 29 : A0A0B4J2A2
# Processing... 30 : A0A0B4J2B5
# Processing... 31 : A0A0B4J2D5
# Processing... 32 : A0A0B4J2D9
# Processing... 33 : A0A0B4J2F0
# Processing... 34 : A0A0C4DH25
# Processing... 35 : A0A0C4DH31
# Processing... 36 : A0A0C4DH34
# Processing... 37 : A0A0C4DH35
# Processing... 38 : A0A0C4DH36
# Processing... 39 : A0A0C4DH38
# Processing... 40 : A0A0C4DH43
# Processing... 41 : A0A0C4DH72
# Processing... 42 : A0A0C4DH73
# Processing... 43 : A0A0G2JRQ6
# Processing... 44 : A0A0J9YW62
# Processing... 45 : A0A0U1RRL7
# Processing... 46 : A0A1W2PQ73
# Processing... 47 : A0A2R8Y619
# Processing... 48 : A0A494C1R9
# Processing... 49 : A0AAG2UWQ9
# Processing... 50 : A0AV96
# Processing... 51 : A0AVF1
# Processing... 52 : A0AVT1
# Processing... 53 : A0FGR8
# Processing... 54 : A0JLT2
# Processing... 55 : A0JNW5
# Processing... 56 : A0M8Q6
# Processing... 57 : A0MZ66
# Processing... 58 : A0PJW6
# Processing... 59 : A0PJW8
# Processing... 60 : A0PK00
# Processing... 61 : A1A4S6
# Processing... 62 : A1A5D9
# Processing... 63 : A1IGU5
# Processing... 64 : A1L020
# Processing... 65 : A1L0T0
# Processing... 66 : A1L170
# Processing... 67 : A1L188
# Processing... 68 : A1L390
# Processing... 69 : A1L4H1
# Processing... 70 : A1X283
# Processing... 71 : A1XBS5
# Processing... 72 : A1Z1Q3
# Processing... 73 : A2AJT9
# Processing... 74 : A2NJV5
# Processing... 75 : A2RRP1
# Processing... 76 : A2RU49
# Processing... 77 : A2RUC4
# Processing... 78 : A2RUS2
# Processing... 79 : A3KMH1
# Processing... 80 : A3KN83
# Processing... 81 : A4D126
# Processing... 82 : A4D161
# Processing... 83 : A4D1E9
# Processing... 84 : A4D1P6
# Processing... 85 : A4D1S5
# Processing... 86 : A4D1U4
# Processing... 87 : A4D2B0
# Processing... 88 : A4FU01
# Processing... 89 : A5A3E0
# Processing... 90 : A5D8V6
# Processing... 91 : A5PLL7
# Processing... 92 : A5PLN9
# Processing... 93 : A5YKK6
# Processing... 94 : A5YM69
# Processing... 95 : A6NC98
# Processing... 96 : A6ND36
# Processing... 97 : A6NDB9
# Processing... 98 : A6NDG6
# Processing... 99 : A6NDU8
# Processing... 100 : A6NED2
# Processing... 101 : A6NEL2
# Processing... 102 : A6NEQ0
# Processing... 103 : A6NFI3
# Processing... 104 : A6NFQ2
# Processing... 105 : A6NGU5
# Processing... 106 : A6NHL2
# Processing... 107 : A6NHQ2
# Processing... 108 : A6NHR9
# Processing... 109 : A6NHX0
# Processing... 110 : A6NI72
# Processing... 111 : A6NI73
# Processing... 112 : A6NI79
# Processing... 113 : A6NIH7
# Processing... 114 : A6NJ78
# Processing... 115 : A6NK58
# Processing... 116 : A6NKD9
# Processing... 117 : A6NKN8
# Processing... 118 : A6NKT7
# Processing... 119 : A6NMZ7
# Processing... 120 : A6NNV3
# Processing... 121 : A6QL63
# Processing... 122 : A7E2V4
# Processing... 123 : A7KAX9
# Processing... 124 : A8CG34
# Processing... 125 : A8K2U0
# Processing... 126 : A8K7I4
# Processing... 127 : A8MPS7
# Processing... 128 : A8MQ03
# Processing... 129 : A8MW92
# Processing... 130 : A8MWD9
# Processing... 131 : A8MXV4
# Processing... 132 : A8MYP8
# Processing... 133 : A8TX70
# Processing... 134 : A9UHW6
# Processing... 135 : B0FP48
# Processing... 136 : B0I1T2
# Processing... 137 : B2RN74
# Processing... 138 : B2RTY4
# Processing... 139 : B3EWG3
# Processing... 140 : B7ZAQ6
# Processing... 141 : B7ZBB8
# Processing... 142 : B9A064
# Processing... 143 : C4AMC7
# Processing... 144 : C9J798
# Processing... 145 : C9J7I0
# Processing... 146 : C9JI98
# Processing... 147 : C9JLW8
# Processing... 148 : D6REC4
# Processing... 149 : D6RF30
# Processing... 150 : D6RIA3
# Processing... 151 : E7ERA6
# Processing... 152 : E9PAV3
# Processing... 153 : E9PRG8
# Processing... 154 : G9CGD6
# Processing... 155 : L0R819
# Processing... 156 : O00115
# Processing... 157 : O00116
# Processing... 158 : O00124
# Processing... 159 : O00139
# Processing... 160 : O00142
# Processing... 161 : O00148
# Processing... 162 : O00151
# Processing... 163 : O00154
# Processing... 164 : O00159
# Processing... 165 : O00160
# Processing... 166 : O00161
# Processing... 167 : O00165
# Processing... 168 : O00170
# Processing... 169 : O00178
# Processing... 170 : O00180
# Processing... 171 : O00182
# Processing... 172 : O00186
# Processing... 173 : O00187
# Processing... 174 : O00189
# Processing... 175 : O00192
# Processing... 176 : O00193
# Processing... 177 : O00194
# Processing... 178 : O00203
# Processing... 179 : O00204
# Processing... 180 : O00214
# Processing... 181 : O00217
# Processing... 182 : O00219
# Processing... 183 : O00220
# Processing... 184 : O00221
# Processing... 185 : O00231
# Processing... 186 : O00232
# Processing... 187 : O00233
# Processing... 188 : O00244
# Processing... 189 : O00255
# Processing... 190 : O00257
# Processing... 191 : O00264
# Processing... 192 : O00267
# Processing... 193 : O00268
# Processing... 194 : O00273
# Processing... 195 : O00287
# Processing... 196 : O00291
# Processing... 197 : O00299
# Processing... 198 : O00303
# Processing... 199 : O00308
# Processing... 200 : O00322
# Processing... 201 : O00329
# Processing... 202 : O00330
# Processing... 203 : O00339
# Processing... 204 : O00391
# Processing... 205 : O00399
# Processing... 206 : O00400
# Processing... 207 : O00401
# Processing... 208 : O00410
# Processing... 209 : O00411
# Processing... 210 : O00418
# Processing... 211 : O00422
# Processing... 212 : O00423
# Processing... 213 : O00425
# Processing... 214 : O00429
# Processing... 215 : O00442
# Processing... 216 : O00443
# Processing... 217 : O00458
# Processing... 218 : O00459
# Processing... 219 : O00461
# Processing... 220 : O00462
# Processing... 221 : O00468
# Processing... 222 : O00469
# Processing... 223 : O00470
# Processing... 224 : O00471
# Processing... 225 : O00478
# Processing... 226 : O00479
# Processing... 227 : O00481
# Processing... 228 : O00483
# Processing... 229 : O00487
# Processing... 230 : O00488
# Processing... 231 : O00499
# Processing... 232 : O00505
# Processing... 233 : O00506
# Processing... 234 : O00507
# Processing... 235 : O00512
# Processing... 236 : O00515
# Processing... 237 : O00519
# Processing... 238 : O00526
# Processing... 239 : O00534
# Processing... 240 : O00541
# Processing... 241 : O00559
# Processing... 242 : O00560
# Processing... 243 : O00562
# Processing... 244 : O00566
# Processing... 245 : O00567
# Processing... 246 : O00571
# Processing... 247 : O00584
# Processing... 248 : O00592
# Processing... 249 : O00602
# Processing... 250 : O00625
# Processing... 251 : O00628
# Processing... 252 : O00629
# Processing... 253 : O00635
# Processing... 254 : O00712
# Processing... 255 : O00743
# Processing... 256 : O00746
# Processing... 257 : O00748
# Processing... 258 : O00750
# Processing... 259 : O00754
# Processing... 260 : O00757
# Processing... 261 : O00762
# Processing... 262 : O00764
# Processing... 263 : O00767
# Processing... 264 : O14493
# Processing... 265 : O14494
# Processing... 266 : O14495
# Processing... 267 : O14497
# Processing... 268 : O14498
# Processing... 269 : O14508
# Processing... 270 : O14519
# Processing... 271 : O14521
# Processing... 272 : O14523
# Processing... 273 : O14524
# Processing... 274 : O14530
# Processing... 275 : O14545
# Processing... 276 : O14548
# Processing... 277 : O14558
# Processing... 278 : O14561
# Processing... 279 : O14562
# Processing... 280 : O14579
# Processing... 281 : O14593
# Processing... 282 : O14602
# Processing... 283 : O14617
# Processing... 284 : O14618
# Processing... 285 : O14628
# Processing... 286 : O14639
# Processing... 287 : O14641
# Processing... 288 : O14646
# Processing... 289 : O14647
# Processing... 290 : O14653
# Processing... 291 : O14656
# Processing... 292 : O14657
# Processing... 293 : O14662
# Processing... 294 : O14672
# Processing... 295 : O14678
# Processing... 296 : O14681
# Processing... 297 : O14683
# Processing... 298 : O14684
# Processing... 299 : O14686
# Processing... 300 : O14727
# Processing... 301 : O14730
# Processing... 302 : O14732
# Processing... 303 : O14733
# Processing... 304 : O14734
# Processing... 305 : O14735
# Processing... 306 : O14737
# Processing... 307 : O14744
# Processing... 308 : O14745
# Processing... 309 : O14753
# Processing... 310 : O14757
# Processing... 311 : O14763
# Processing... 312 : O14772
# Processing... 313 : O14773
# Processing... 314 : O14775
# Processing... 315 : O14776
# Processing... 316 : O14777
# Processing... 317 : O14786
# Processing... 318 : O14787
# Processing... 319 : O14788
# Processing... 320 : O14791
# Processing... 321 : O14792
# Processing... 322 : O14795
# Processing... 323 : O14802
# Processing... 324 : O14815
# Processing... 325 : O14818
# Processing... 326 : O14828
# Processing... 327 : O14832
# Processing... 328 : O14841
# Processing... 329 : O14867
# Processing... 330 : O14874
# Processing... 331 : O14879
# Processing... 332 : O14880
# Processing... 333 : O14893
# Processing... 334 : O14896
# Processing... 335 : O14907
# Processing... 336 : O14908
# Processing... 337 : O14910
# Processing... 338 : O14920
# Processing... 339 : O14924
# Processing... 340 : O14925
# Processing... 341 : O14929
# Processing... 342 : O14933
# Processing... 343 : O14936
# Processing... 344 : O14939
# Processing... 345 : O14949
# Processing... 346 : O14950
# Processing... 347 : O14957
# Processing... 348 : O14964
# Processing... 349 : O14965
# Processing... 350 : O14966
# Processing... 351 : O14972
# Processing... 352 : O14974
# Processing... 353 : O14975
# Processing... 354 : O14976
# Processing... 355 : O14979
# Processing... 356 : O14980
# Processing... 357 : O14981
# Processing... 358 : O15013
# Processing... 359 : O15014
# Processing... 360 : O15020
# Processing... 361 : O15021
# Processing... 362 : O15027
# Processing... 363 : O15031
# Processing... 364 : O15037
# Processing... 365 : O15040
# Processing... 366 : O15042
# Processing... 367 : O15047
# Processing... 368 : O15049
# Processing... 369 : O15056
# Processing... 370 : O15061
# Processing... 371 : O15066
# Processing... 372 : O15067
# Processing... 373 : O15068
# Processing... 374 : O15084
# Processing... 375 : O15085
# Processing... 376 : O15091
# Processing... 377 : O15111
# Processing... 378 : O15116
# Processing... 379 : O15117
# Processing... 380 : O15118
# Processing... 381 : O15119
# Processing... 382 : O15120
# Processing... 383 : O15121
# Processing... 384 : O15123
# Processing... 385 : O15126
# Processing... 386 : O15127
# Processing... 387 : O15143
# Processing... 388 : O15144
# Processing... 389 : O15145
# Processing... 390 : O15155
# Processing... 391 : O15156
# Processing... 392 : O15160
# Processing... 393 : O15162
# Processing... 394 : O15164
# Processing... 395 : O15169
# Processing... 396 : O15173
# Processing... 397 : O15182
# Processing... 398 : O15195
# Processing... 399 : O15197
# Processing... 400 : O15211
# Processing... 401 : O15212
# Processing... 402 : O15213
# Processing... 403 : O15217
# Processing... 404 : O15226
# Processing... 405 : O15228
# Processing... 406 : O15230
# Processing... 407 : O15231
# Processing... 408 : O15234
# Processing... 409 : O15235
# Processing... 410 : O15239
# Processing... 411 : O15243
# Processing... 412 : O15247
# Processing... 413 : O15254
# Processing... 414 : O15258
# Processing... 415 : O15260
# Processing... 416 : O15264
# Processing... 417 : O15265
# Processing... 418 : O15269
# Processing... 419 : O15270
# Processing... 420 : O15294
# Processing... 421 : O15305
# Processing... 422 : O15315
# Processing... 423 : O15321
# Processing... 424 : O15327
# Processing... 425 : O15344
# Processing... 426 : O15347
# Processing... 427 : O15350
# Processing... 428 : O15355
# Processing... 429 : O15357
# Processing... 430 : O15371
# Processing... 431 : O15372
# Processing... 432 : O15379
# Processing... 433 : O15381
# Processing... 434 : O15382
# Processing... 435 : O15389
# Processing... 436 : O15392
# Processing... 437 : O15393
# Processing... 438 : O15397
# Processing... 439 : O15400
# Processing... 440 : O15405
# Processing... 441 : O15417
# Processing... 442 : O15427
# Processing... 443 : O15431
# Processing... 444 : O15438
# Processing... 445 : O15439
# Processing... 446 : O15440
# Processing... 447 : O15446
# Processing... 448 : O15455
# Processing... 449 : O15460
# Processing... 450 : O15481
# Processing... 451 : O15484
# Processing... 452 : O15498
# Processing... 453 : O15503
# Processing... 454 : O15504
# Processing... 455 : O15511
# Processing... 456 : O15514
# Processing... 457 : O15523
# Processing... 458 : O15530
# Processing... 459 : O15533
# Processing... 460 : O15541
# Processing... 461 : O15551
# Processing... 462 : O15554
# Processing... 463 : O43143
# Processing... 464 : O43148
# Processing... 465 : O43149
# Processing... 466 : O43150
# Processing... 467 : O43156
# Processing... 468 : O43157
# Processing... 469 : O43159
# Processing... 470 : O43164
# Processing... 471 : O43166
# Processing... 472 : O43169
# Processing... 473 : O43172
# Processing... 474 : O43175
# Processing... 475 : O43181
# Processing... 476 : O43182
# Processing... 477 : O43189
# Processing... 478 : O43194
# Processing... 479 : O43237
# Processing... 480 : O43240
# Processing... 481 : O43242
# Processing... 482 : O43251
# Processing... 483 : O43252
# Processing... 484 : O43264
# Processing... 485 : O43272
# Processing... 486 : O43278
# Processing... 487 : O43281
# Processing... 488 : O43290
# Processing... 489 : O43291
# Processing... 490 : O43292
# Processing... 491 : O43293
# Processing... 492 : O43294
# Processing... 493 : O43295
# Processing... 494 : O43299
# Processing... 495 : O43301
# Processing... 496 : O43303
# Processing... 497 : O43306
# Processing... 498 : O43310
# Processing... 499 : O43312
# Processing... 500 : O43314
# Processing... 501 : O43318
# Processing... 502 : O43324
# Processing... 503 : O43353
# Processing... 504 : O43390
# Processing... 505 : O43395
# Processing... 506 : O43396
# Processing... 507 : O43399
# Processing... 508 : O43402
# Processing... 509 : O43414
# Processing... 510 : O43422
# Processing... 511 : O43426
# Processing... 512 : O43427
# Processing... 513 : O43432
# Processing... 514 : O43435
# Processing... 515 : O43447
# Processing... 516 : O43451
# Processing... 517 : O43464
# Processing... 518 : O43474
# Processing... 519 : O43488
# Processing... 520 : O43491
# Processing... 521 : O43493
# Processing... 522 : O43504
# Processing... 523 : O43505
# Processing... 524 : O43513
# Processing... 525 : O43516
# Processing... 526 : O43520
# Processing... 527 : O43524
# Processing... 528 : O43556
# Processing... 529 : O43567
# Processing... 530 : O43570
# Processing... 531 : O43572
# Processing... 532 : O43581
# Processing... 533 : O43583
# Processing... 534 : O43592
# Processing... 535 : O43598
# Processing... 536 : O43615
# Processing... 537 : O43617
# Processing... 538 : O43633
# Processing... 539 : O43639
# Processing... 540 : O43653
# Processing... 541 : O43657
# Processing... 542 : O43660
# Processing... 543 : O43663
# Processing... 544 : O43665
# Processing... 545 : O43670
# Processing... 546 : O43674
# Processing... 547 : O43676
# Processing... 548 : O43677
# Processing... 549 : O43678
# Processing... 550 : O43681
# Processing... 551 : O43684
# Processing... 552 : O43688
# Processing... 553 : O43704
# Processing... 554 : O43707
# Processing... 555 : O43708
# Processing... 556 : O43709
# Processing... 557 : O43715
# Processing... 558 : O43716
# Processing... 559 : O43719
# Processing... 560 : O43734
# Processing... 561 : O43741
# Processing... 562 : O43745
# Processing... 563 : O43747
# Processing... 564 : O43752
# Processing... 565 : O43759
# Processing... 566 : O43760
# Processing... 567 : O43765
# Processing... 568 : O43766
# Processing... 569 : O43768
# Processing... 570 : O43772
# Processing... 571 : O43776
# Processing... 572 : O43790
# Processing... 573 : O43795
# Processing... 574 : O43805
# Processing... 575 : O43809
# Processing... 576 : O43813
# Processing... 577 : O43815
# Processing... 578 : O43818
# Processing... 579 : O43819
# Processing... 580 : O43822
# Processing... 581 : O43823
# Processing... 582 : O43824
# Processing... 583 : O43826
# Processing... 584 : O43837
# Processing... 585 : O43847
# Processing... 586 : O43852
# Processing... 587 : O43865
# Processing... 588 : O43866
# Processing... 589 : O43896
# Processing... 590 : O43903
# Processing... 591 : O43909
# Processing... 592 : O43913
# Processing... 593 : O43914
# Processing... 594 : O43920
# Processing... 595 : O43924
# Processing... 596 : O43929
# Processing... 597 : O43933
# Processing... 598 : O60216
# Processing... 599 : O60218
# Processing... 600 : O60220
# Processing... 601 : O60229
# Processing... 602 : O60231
# Processing... 603 : O60232
# Processing... 604 : O60234
# Processing... 605 : O60237
# Processing... 606 : O60238
# Processing... 607 : O60240
# Processing... 608 : O60244
# Processing... 609 : O60245
# Processing... 610 : O60248
# Processing... 611 : O60256
# Processing... 612 : O60262
# Processing... 613 : O60264
# Processing... 614 : O60266
# Processing... 615 : O60271
# Processing... 616 : O60281
# Processing... 617 : O60282
# Processing... 618 : O60287
# Processing... 619 : O60291
# Processing... 620 : O60292
# Processing... 621 : O60293
# Processing... 622 : O60299
# Processing... 623 : O60306
# Processing... 624 : O60313
# Processing... 625 : O60318
# Processing... 626 : O60331
# Processing... 627 : O60333
# Processing... 628 : O60341
# Processing... 629 : O60343
# Processing... 630 : O60346
# Processing... 631 : O60347
# Processing... 632 : O60353
# Processing... 633 : O60361
# Processing... 634 : O60381
# Processing... 635 : O60427
# Processing... 636 : O60437
# Processing... 637 : O60443
# Processing... 638 : O60449
# Processing... 639 : O60462
# Processing... 640 : O60476
# Processing... 641 : O60487
# Processing... 642 : O60488
# Processing... 643 : O60493
# Processing... 644 : O60496
# Processing... 645 : O60499
# Processing... 646 : O60502
# Processing... 647 : O60504
# Processing... 648 : O60506
# Processing... 649 : O60507
# Processing... 650 : O60508
# Processing... 651 : O60512
# Processing... 652 : O60513
# Processing... 653 : O60518
# Processing... 654 : O60524
# Processing... 655 : O60547
# Processing... 656 : O60551
# Processing... 657 : O60563
# Processing... 658 : O60565
# Processing... 659 : O60568
# Processing... 660 : O60573
# Processing... 661 : O60583
# Processing... 662 : O60602
# Processing... 663 : O60603
# Processing... 664 : O60610
# Processing... 665 : O60613
# Processing... 666 : O60635
# Processing... 667 : O60641
# Processing... 668 : O60645
# Processing... 669 : O60658
# Processing... 670 : O60664
# Processing... 671 : O60669
# Processing... 672 : O60671
# Processing... 673 : O60675
# Processing... 674 : O60678
# Processing... 675 : O60683
# Processing... 676 : O60684
# Processing... 677 : O60687
# Processing... 678 : O60701
# Processing... 679 : O60704
# Processing... 680 : O60711
# Processing... 681 : O60716
# Processing... 682 : O60725
# Processing... 683 : O60733
# Processing... 684 : O60739
# Processing... 685 : O60749
# Processing... 686 : O60760
# Processing... 687 : O60762
# Processing... 688 : O60763
# Processing... 689 : O60779
# Processing... 690 : O60783
# Processing... 691 : O60784
# Processing... 692 : O60812
# Processing... 693 : O60825
# Processing... 694 : O60826
# Processing... 695 : O60828
# Processing... 696 : O60830
# Processing... 697 : O60831
# Processing... 698 : O60832
# Processing... 699 : O60841
# Processing... 700 : O60858
# Processing... 701 : O60861
# Processing... 702 : O60869
# Processing... 703 : O60870
# Processing... 704 : O60879
# Processing... 705 : O60880
# Processing... 706 : O60884
# Processing... 707 : O60885
# Processing... 708 : O60888
# Processing... 709 : O60906
# Processing... 710 : O60907
# Processing... 711 : O60921
# Processing... 712 : O60925
# Processing... 713 : O60927
# Processing... 714 : O60930
# Processing... 715 : O60934
# Processing... 716 : O60936
# Processing... 717 : O60941
# Processing... 718 : O60942
# Processing... 719 : O75015
# Processing... 720 : O75023
# Processing... 721 : O75027
# Processing... 722 : O75038
# Processing... 723 : O75044
# Processing... 724 : O75051
# Processing... 725 : O75052
# Processing... 726 : O75054
# Processing... 727 : O75063
# Processing... 728 : O75064
# Processing... 729 : O75071
# Processing... 730 : O75081
# Processing... 731 : O75083
# Processing... 732 : O75084
# Processing... 733 : O75094
# Processing... 734 : O75095
# Processing... 735 : O75110
# Processing... 736 : O75112
# Processing... 737 : O75113
# Processing... 738 : O75116
# Processing... 739 : O75121
# Processing... 740 : O75122
# Processing... 741 : O75127
# Processing... 742 : O75131
# Processing... 743 : O75140
# Processing... 744 : O75143
# Processing... 745 : O75146
# Processing... 746 : O75150
# Processing... 747 : O75151
# Processing... 748 : O75152
# Processing... 749 : O75153
# Processing... 750 : O75157
# Processing... 751 : O75164
# Processing... 752 : O75165
# Processing... 753 : O75167
# Processing... 754 : O75170
# Processing... 755 : O75175
# Processing... 756 : O75179
# Processing... 757 : O75182
# Processing... 758 : O75185
# Processing... 759 : O75190
# Processing... 760 : O75191
# Processing... 761 : O75192
# Processing... 762 : O75208
# Processing... 763 : O75223
# Processing... 764 : O75251
# Processing... 765 : O75298
# Processing... 766 : O75306
# Processing... 767 : O75312
# Processing... 768 : O75317
# Processing... 769 : O75319
# Processing... 770 : O75323
# Processing... 771 : O75326
# Processing... 772 : O75330
# Processing... 773 : O75339
# Processing... 774 : O75340
# Processing... 775 : O75347
# Processing... 776 : O75348
# Processing... 777 : O75351
# Processing... 778 : O75352
# Processing... 779 : O75354
# Processing... 780 : O75355
# Processing... 781 : O75356
# Processing... 782 : O75362
# Processing... 783 : O75363
# Processing... 784 : O75367
# Processing... 785 : O75368
# Processing... 786 : O75369
# Processing... 787 : O75376
# Processing... 788 : O75379
# Processing... 789 : O75380
# Processing... 790 : O75381
# Processing... 791 : O75382
# Processing... 792 : O75390
# Processing... 793 : O75391
# Processing... 794 : O75394
# Processing... 795 : O75396
# Processing... 796 : O75400
# Processing... 797 : O75410
# Processing... 798 : O75414
# Processing... 799 : O75420
# Processing... 800 : O75427
# Processing... 801 : O75431
# Processing... 802 : O75436
# Processing... 803 : O75438
# Processing... 804 : O75439
# Processing... 805 : O75445
# Processing... 806 : O75446
# Processing... 807 : O75448
# Processing... 808 : O75449
# Processing... 809 : O75452
# Processing... 810 : O75475
# Processing... 811 : O75477
# Processing... 812 : O75487
# Processing... 813 : O75489
# Processing... 814 : O75494
# Processing... 815 : O75503
# Processing... 816 : O75506
# Processing... 817 : O75509
# Processing... 818 : O75521
# Processing... 819 : O75525
# Processing... 820 : O75528
# Processing... 821 : O75529
# Processing... 822 : O75530
# Processing... 823 : O75531
# Processing... 824 : O75533
# Processing... 825 : O75534
# Processing... 826 : O75553
# Processing... 827 : O75554
# Processing... 828 : O75558
# Processing... 829 : O75563
# Processing... 830 : O75569
# Processing... 831 : O75570
# Processing... 832 : O75575
# Processing... 833 : O75582
# Processing... 834 : O75586
# Processing... 835 : O75592
# Processing... 836 : O75594
# Processing... 837 : O75600
# Processing... 838 : O75607
# Processing... 839 : O75608
# Processing... 840 : O75616
# Processing... 841 : O75629
# Processing... 842 : O75631
# Processing... 843 : O75635
# Processing... 844 : O75636
# Processing... 845 : O75643
# Processing... 846 : O75648
# Processing... 847 : O75663
# Processing... 848 : O75665
# Processing... 849 : O75674
# Processing... 850 : O75676
# Processing... 851 : O75683
# Processing... 852 : O75688
# Processing... 853 : O75689
# Processing... 854 : O75691
# Processing... 855 : O75694
# Processing... 856 : O75695
# Processing... 857 : O75716
# Processing... 858 : O75717
# Processing... 859 : O75718
# Processing... 860 : O75746
# Processing... 861 : O75752
# Processing... 862 : O75762
# Processing... 863 : O75764
# Processing... 864 : O75781
# Processing... 865 : O75787
# Processing... 866 : O75791
# Processing... 867 : O75792
# Processing... 868 : O75794
# Processing... 869 : O75795
# Processing... 870 : O75808
# Processing... 871 : O75817
# Processing... 872 : O75818
# Processing... 873 : O75821
# Processing... 874 : O75822
# Processing... 875 : O75828
# Processing... 876 : O75832
# Processing... 877 : O75841
# Processing... 878 : O75843
# Processing... 879 : O75844
# Processing... 880 : O75864
# Processing... 881 : O75865
# Processing... 882 : O75874
# Processing... 883 : O75879
# Processing... 884 : O75880
# Processing... 885 : O75881
# Processing... 886 : O75882
# Processing... 887 : O75884
# Processing... 888 : O75886
# Processing... 889 : O75888
# Processing... 890 : O75891
# Processing... 891 : O75907
# Processing... 892 : O75909
# Processing... 893 : O75911
# Processing... 894 : O75915
# Processing... 895 : O75923
# Processing... 896 : O75925
# Processing... 897 : O75934
# Processing... 898 : O75935
# Processing... 899 : O75937
# Processing... 900 : O75940
# Processing... 901 : O75943
# Processing... 902 : O75947
# Processing... 903 : O75953
# Processing... 904 : O75954
# Processing... 905 : O75955
# Processing... 906 : O75962
# Processing... 907 : O75964
# Processing... 908 : O75970
# Processing... 909 : O75976
# Processing... 910 : O75995
# Processing... 911 : O76003
# Processing... 912 : O76013
# Processing... 913 : O76015
# Processing... 914 : O76021
# Processing... 915 : O76024
# Processing... 916 : O76027
# Processing... 917 : O76031
# Processing... 918 : O76038
# Processing... 919 : O76041
# Processing... 920 : O76054
# Processing... 921 : O76061
# Processing... 922 : O76062
# Processing... 923 : O76070
# Processing... 924 : O76071
# Processing... 925 : O76074
# Processing... 926 : O76076
# Processing... 927 : O76080
# Processing... 928 : O76082
# Processing... 929 : O76094
# Processing... 930 : O76095
# Processing... 931 : O94760
# Processing... 932 : O94761
# Processing... 933 : O94762
# Processing... 934 : O94763
# Processing... 935 : O94766
# Processing... 936 : O94768
# Processing... 937 : O94776
# Processing... 938 : O94782
# Processing... 939 : O94788
# Processing... 940 : O94804
# Processing... 941 : O94811
# Processing... 942 : O94819
# Processing... 943 : O94822
# Processing... 944 : O94823
# Processing... 945 : O94826
# Processing... 946 : O94829
# Processing... 947 : O94830
# Processing... 948 : O94832
# Processing... 949 : O94842
# Processing... 950 : O94851
# Processing... 951 : O94855
# Processing... 952 : O94864
# Processing... 953 : O94868
# Processing... 954 : O94874
# Processing... 955 : O94875
# Processing... 956 : O94876
# Processing... 957 : O94880
# Processing... 958 : O94885
# Processing... 959 : O94886
# Processing... 960 : O94887
# Processing... 961 : O94888
# Processing... 962 : O94901
# Processing... 963 : O94903
# Processing... 964 : O94905
# Processing... 965 : O94906
# Processing... 966 : O94907
# Processing... 967 : O94911
# Processing... 968 : O94913
# Processing... 969 : O94915
# Processing... 970 : O94916
# Processing... 971 : O94919
# Processing... 972 : O94921
# Processing... 973 : O94923
# Processing... 974 : O94925
# Processing... 975 : O94927
# Processing... 976 : O94929
# Processing... 977 : O94952
# Processing... 978 : O94953
# Processing... 979 : O94955
# Processing... 980 : O94964
# Processing... 981 : O94966
# Processing... 982 : O94967
# Processing... 983 : O94973
# Processing... 984 : O94979
# Processing... 985 : O94985
# Processing... 986 : O94988
# Processing... 987 : O94992
# Processing... 988 : O95049
# Processing... 989 : O95070
# Processing... 990 : O95071
# Processing... 991 : O95081
# Processing... 992 : O95084
# Processing... 993 : O95104
# Processing... 994 : O95136
# Processing... 995 : O95139
# Processing... 996 : O95140
# Processing... 997 : O95147
# Processing... 998 : O95149
# Processing... 999 : O95154
# Processing... 1000 : O95155
# Processing... 1001 : O95159
# Processing... 1002 : O95163
# Processing... 1003 : O95164
# Processing... 1004 : O95166
# Processing... 1005 : O95167
# Processing... 1006 : O95168
# Processing... 1007 : O95169
# Processing... 1008 : O95171
# Processing... 1009 : O95178
# Processing... 1010 : O95182
# Processing... 1011 : O95183
# Processing... 1012 : O95197
# Processing... 1013 : O95199
# Processing... 1014 : O95202
# Processing... 1015 : O95208
# Processing... 1016 : O95210
# Processing... 1017 : O95218
# Processing... 1018 : O95219
# Processing... 1019 : O95232
# Processing... 1020 : O95235
# Processing... 1021 : O95236
# Processing... 1022 : O95239
# Processing... 1023 : O95248
# Processing... 1024 : O95249
# Processing... 1025 : O95251
# Processing... 1026 : O95260
# Processing... 1027 : O95273
# Processing... 1028 : O95274
# Processing... 1029 : O95292
# Processing... 1030 : O95294
# Processing... 1031 : O95295
# Processing... 1032 : O95297
# Processing... 1033 : O95298
# Processing... 1034 : O95299
# Processing... 1035 : O95302
# Processing... 1036 : O95319
# Processing... 1037 : O95336
# Processing... 1038 : O95340
# Processing... 1039 : O95347
# Processing... 1040 : O95352
# Processing... 1041 : O95359
# Processing... 1042 : O95361
# Processing... 1043 : O95363
# Processing... 1044 : O95365
# Processing... 1045 : O95372
# Processing... 1046 : O95373
# Processing... 1047 : O95376
# Processing... 1048 : O95377
# Processing... 1049 : O95379
# Processing... 1050 : O95382
# Processing... 1051 : O95391
# Processing... 1052 : O95394
# Processing... 1053 : O95396
# Processing... 1054 : O95400
# Processing... 1055 : O95405
# Processing... 1056 : O95415
# Processing... 1057 : O95425
# Processing... 1058 : O95427
# Processing... 1059 : O95428
# Processing... 1060 : O95429
# Processing... 1061 : O95433
# Processing... 1062 : O95445
# Processing... 1063 : O95452
# Processing... 1064 : O95453
# Processing... 1065 : O95456
# Processing... 1066 : O95461
# Processing... 1067 : O95466
# Processing... 1068 : O95470
# Processing... 1069 : O95471
# Processing... 1070 : O95477
# Processing... 1071 : O95478
# Processing... 1072 : O95479
# Processing... 1073 : O95486
# Processing... 1074 : O95487
# Processing... 1075 : O95490
# Processing... 1076 : O95497
# Processing... 1077 : O95498
# Processing... 1078 : O95503
# Processing... 1079 : O95528
# Processing... 1080 : O95544
# Processing... 1081 : O95551
# Processing... 1082 : O95562
# Processing... 1083 : O95563
# Processing... 1084 : O95568
# Processing... 1085 : O95571
# Processing... 1086 : O95573
# Processing... 1087 : O95602
# Processing... 1088 : O95613
# Processing... 1089 : O95619
# Processing... 1090 : O95625
# Processing... 1091 : O95628
# Processing... 1092 : O95630
# Processing... 1093 : O95639
# Processing... 1094 : O95671
# Processing... 1095 : O95674
# Processing... 1096 : O95678
# Processing... 1097 : O95684
# Processing... 1098 : O95685
# Processing... 1099 : O95696
# Processing... 1100 : O95707
# Processing... 1101 : O95714
# Processing... 1102 : O95716
# Processing... 1103 : O95721
# Processing... 1104 : O95747
# Processing... 1105 : O95749
# Processing... 1106 : O95755
# Processing... 1107 : O95757
# Processing... 1108 : O95758
# Processing... 1109 : O95759
# Processing... 1110 : O95760
# Processing... 1111 : O95777
# Processing... 1112 : O95782
# Processing... 1113 : O95785
# Processing... 1114 : O95786
# Processing... 1115 : O95793
# Processing... 1116 : O95801
# Processing... 1117 : O95810
# Processing... 1118 : O95816
# Processing... 1119 : O95817
# Processing... 1120 : O95819
# Processing... 1121 : O95822
# Processing... 1122 : O95825
# Processing... 1123 : O95831
# Processing... 1124 : O95832
# Processing... 1125 : O95833
# Processing... 1126 : O95834
# Processing... 1127 : O95837
# Processing... 1128 : O95848
# Processing... 1129 : O95857
# Processing... 1130 : O95858
# Processing... 1131 : O95861
# Processing... 1132 : O95864
# Processing... 1133 : O95865
# Processing... 1134 : O95870
# Processing... 1135 : O95873
# Processing... 1136 : O95881
# Processing... 1137 : O95900
# Processing... 1138 : O95905
# Processing... 1139 : O95926
# Processing... 1140 : O95931
# Processing... 1141 : O95965
# Processing... 1142 : O95967
# Processing... 1143 : O95980
# Processing... 1144 : O95983
# Processing... 1145 : O95985
# Processing... 1146 : O95989
# Processing... 1147 : O95994
# Processing... 1148 : O95999
# Processing... 1149 : O96000
# Processing... 1150 : O96005
# Processing... 1151 : O96006
# Processing... 1152 : O96007
# Processing... 1153 : O96008
# Processing... 1154 : O96011
# Processing... 1155 : O96013
# Processing... 1156 : O96015
# Processing... 1157 : O96017
# Processing... 1158 : O96019
# Processing... 1159 : O96028
# Processing... 1160 : P00167
# Processing... 1161 : P00325
# Processing... 1162 : P00326
# Processing... 1163 : P00338
# Processing... 1164 : P00352
# Processing... 1165 : P00367
# Processing... 1166 : P00374
# Processing... 1167 : P00387
# Processing... 1168 : P00390
# Processing... 1169 : P00403
# Processing... 1170 : P00414
# Processing... 1171 : P00441
# Processing... 1172 : P00450
# Processing... 1173 : P00488
# Processing... 1174 : P00491
# Processing... 1175 : P00492
# Processing... 1176 : P00505
# Processing... 1177 : P00519
# Processing... 1178 : P00533
# Processing... 1179 : P00558
# Processing... 1180 : P00568
# Processing... 1181 : P00734
# Processing... 1182 : P00736
# Processing... 1183 : P00738
# Processing... 1184 : P00739
# Processing... 1185 : P00740
# Processing... 1186 : P00742
# Processing... 1187 : P00746
# Processing... 1188 : P00747
# Processing... 1189 : P00748
# Processing... 1190 : P00749
# Processing... 1191 : P00750
# Processing... 1192 : P00751
# Processing... 1193 : P00797
# Processing... 1194 : P00813
# Processing... 1195 : P00846
# Processing... 1196 : P00915
# Processing... 1197 : P00918
# Processing... 1198 : P00966
# Processing... 1199 : P00973
# Processing... 1200 : P00995
# Processing... 1201 : P01008
# Processing... 1202 : P01009
# Processing... 1203 : P01011
# Processing... 1204 : P01019
# Processing... 1205 : P01023
# Processing... 1206 : P01024
# Processing... 1207 : P01031
# Processing... 1208 : P01033
# Processing... 1209 : P01034
# Processing... 1210 : P01037
# Processing... 1211 : P01040
# Processing... 1212 : P01042
# Processing... 1213 : P01111
# Processing... 1214 : P01112
# Processing... 1215 : P01116
# Processing... 1216 : P01130
# Processing... 1217 : P01137
# Processing... 1218 : P01344
# Processing... 1219 : P01591
# Processing... 1220 : P01593
# Processing... 1221 : P01597
# Processing... 1222 : P01599
# Processing... 1223 : P01602
# Processing... 1224 : P01619
# Processing... 1225 : P01624
# Processing... 1226 : P01699
# Processing... 1227 : P01700
# Processing... 1228 : P01701
# Processing... 1229 : P01703
# Processing... 1230 : P01704
# Processing... 1231 : P01705
# Processing... 1232 : P01709
# Processing... 1233 : P01714
# Processing... 1234 : P01717
# Processing... 1235 : P01718
# Processing... 1236 : P01721
# Processing... 1237 : P01732
# Processing... 1238 : P01742
# Processing... 1239 : P01743
# Processing... 1240 : P01766
# Processing... 1241 : P01768
# Processing... 1242 : P01780
# Processing... 1243 : P01782
# Processing... 1244 : P01833
# Processing... 1245 : P01834
# Processing... 1246 : P01854
# Processing... 1247 : P01857
# Processing... 1248 : P01859
# Processing... 1249 : P01860
# Processing... 1250 : P01861
# Processing... 1251 : P01871
# Processing... 1252 : P01876
# Processing... 1253 : P01877
# Processing... 1254 : P01880
# Processing... 1255 : P01889
# Processing... 1256 : P01893
# Processing... 1257 : P01903
# Processing... 1258 : P01906
# Processing... 1259 : P01911
# Processing... 1260 : P01920
# Processing... 1261 : P02008
# Processing... 1262 : P02042
# Processing... 1263 : P02100
# Processing... 1264 : P02144
# Processing... 1265 : P02452
# Processing... 1266 : P02458
# Processing... 1267 : P02461
# Processing... 1268 : P02462
# Processing... 1269 : P02511
# Processing... 1270 : P02533
# Processing... 1271 : P02538
# Processing... 1272 : P02545
# Processing... 1273 : P02549
# Processing... 1274 : P02585
# Processing... 1275 : P02647
# Processing... 1276 : P02649
# Processing... 1277 : P02652
# Processing... 1278 : P02654
# Processing... 1279 : P02655
# Processing... 1280 : P02656
# Processing... 1281 : P02671
# Processing... 1282 : P02675
# Processing... 1283 : P02679
# Processing... 1284 : P02686
# Processing... 1285 : P02724
# Processing... 1286 : P02730
# Processing... 1287 : P02741
# Processing... 1288 : P02743
# Processing... 1289 : P02745
# Processing... 1290 : P02746
# Processing... 1291 : P02747
# Processing... 1292 : P02748
# Processing... 1293 : P02749
# Processing... 1294 : P02750
# Processing... 1295 : P02751
# Processing... 1296 : P02753
# Processing... 1297 : P02760
# Processing... 1298 : P02763
# Processing... 1299 : P02765
# Processing... 1300 : P02766
# Processing... 1301 : P02768
# Processing... 1302 : P02774
# Processing... 1303 : P02775
# Processing... 1304 : P02776
# Processing... 1305 : P02778
# Processing... 1306 : P02786
# Processing... 1307 : P02787
# Processing... 1308 : P02788
# Processing... 1309 : P02790
# Processing... 1310 : P02792
# Processing... 1311 : P02794
# Processing... 1312 : P02795
# Processing... 1313 : P03886
# Processing... 1314 : P03891
# Processing... 1315 : P03897
# Processing... 1316 : P03905
# Processing... 1317 : P03915
# Processing... 1318 : P03923
# Processing... 1319 : P03928
# Processing... 1320 : P03950
# Processing... 1321 : P03951
# Processing... 1322 : P03952
# Processing... 1323 : P03956
# Processing... 1324 : P03973
# Processing... 1325 : P04003
# Processing... 1326 : P04004
# Processing... 1327 : P04040
# Processing... 1328 : P04049
# Processing... 1329 : P04062
# Processing... 1330 : P04066
# Processing... 1331 : P04070
# Processing... 1332 : P04075
# Processing... 1333 : P04080
# Processing... 1334 : P04083
# Processing... 1335 : P04114
# Processing... 1336 : P04150
# Processing... 1337 : P04155
# Processing... 1338 : P04156
# Processing... 1339 : P04179
# Processing... 1340 : P04180
# Processing... 1341 : P04181
# Processing... 1342 : P04183
# Processing... 1343 : P04196
# Processing... 1344 : P04216
# Processing... 1345 : P04217
# Processing... 1346 : P04233
# Processing... 1347 : P04259
# Processing... 1348 : P04264
# Processing... 1349 : P04271
# Processing... 1350 : P04275
# Processing... 1351 : P04278
# Processing... 1352 : P04279
# Processing... 1353 : P04350
# Processing... 1354 : P04406
# Processing... 1355 : P04424
# Processing... 1356 : P04430
# Processing... 1357 : P04433
# Processing... 1358 : P04439
# Processing... 1359 : P04440
# Processing... 1360 : P04626
# Processing... 1361 : P04632
# Processing... 1362 : P04637
# Processing... 1363 : P04792
# Processing... 1364 : P04798
# Processing... 1365 : P04818
# Processing... 1366 : P04839
# Processing... 1367 : P04843
# Processing... 1368 : P04844
# Processing... 1369 : P04899
# Processing... 1370 : P04920
# Processing... 1371 : P05019
# Processing... 1372 : P05023
# Processing... 1373 : P05026
# Processing... 1374 : P05067
# Processing... 1375 : P05089
# Processing... 1376 : P05090
# Processing... 1377 : P05091
# Processing... 1378 : P05106
# Processing... 1379 : P05107
# Processing... 1380 : P05109
# Processing... 1381 : P05114
# Processing... 1382 : P05120
# Processing... 1383 : P05121
# Processing... 1384 : P05129
# Processing... 1385 : P05141
# Processing... 1386 : P05154
# Processing... 1387 : P05155
# Processing... 1388 : P05156
# Processing... 1389 : P05160
# Processing... 1390 : P05161
# Processing... 1391 : P05164
# Processing... 1392 : P05165
# Processing... 1393 : P05166
# Processing... 1394 : P05177
# Processing... 1395 : P05181
# Processing... 1396 : P05186
# Processing... 1397 : P05187
# Processing... 1398 : P05198
# Processing... 1399 : P05204
# Processing... 1400 : P05362
# Processing... 1401 : P05386
# Processing... 1402 : P05387
# Processing... 1403 : P05388
# Processing... 1404 : P05412
# Processing... 1405 : P05413
# Processing... 1406 : P05423
# Processing... 1407 : P05452
# Processing... 1408 : P05455
# Processing... 1409 : P05496
# Processing... 1410 : P05543
# Processing... 1411 : P05546
# Processing... 1412 : P05549
# Processing... 1413 : P05556
# Processing... 1414 : P05771
# Processing... 1415 : P05783
# Processing... 1416 : P05787
# Processing... 1417 : P05976
# Processing... 1418 : P05997
# Processing... 1419 : P06127
# Processing... 1420 : P06132
# Processing... 1421 : P06213
# Processing... 1422 : P06239
# Processing... 1423 : P06280
# Processing... 1424 : P06310
# Processing... 1425 : P06312
# Processing... 1426 : P06331
# Processing... 1427 : P06340
# Processing... 1428 : P06396
# Processing... 1429 : P06400
# Processing... 1430 : P06454
# Processing... 1431 : P06493
# Processing... 1432 : P06576
# Processing... 1433 : P06681
# Processing... 1434 : P06702
# Processing... 1435 : P06703
# Processing... 1436 : P06727
# Processing... 1437 : P06730
# Processing... 1438 : P06731
# Processing... 1439 : P06732
# Processing... 1440 : P06733
# Processing... 1441 : P06737
# Processing... 1442 : P06744
# Processing... 1443 : P06746
# Processing... 1444 : P06748
# Processing... 1445 : P06753
# Processing... 1446 : P06756
# Processing... 1447 : P06850
# Processing... 1448 : P06865
# Processing... 1449 : P06899
# Processing... 1450 : P07093
# Processing... 1451 : P07099
# Processing... 1452 : P07108
# Processing... 1453 : P07195
# Processing... 1454 : P07196
# Processing... 1455 : P07197
# Processing... 1456 : P07199
# Processing... 1457 : P07203
# Processing... 1458 : P07204
# Processing... 1459 : P07225
# Processing... 1460 : P07237
# Processing... 1461 : P07288
# Processing... 1462 : P07305
# Processing... 1463 : P07311
# Processing... 1464 : P07332
# Processing... 1465 : P07339
# Processing... 1466 : P07355
# Processing... 1467 : P07357
# Processing... 1468 : P07358
# Processing... 1469 : P07359
# Processing... 1470 : P07360
# Processing... 1471 : P07384
# Processing... 1472 : P07437
# Processing... 1473 : P07451
# Processing... 1474 : P07476
# Processing... 1475 : P07477
# Processing... 1476 : P07478
# Processing... 1477 : P07585
# Processing... 1478 : P07602
# Processing... 1479 : P07686
# Processing... 1480 : P07711
# Processing... 1481 : P07737
# Processing... 1482 : P07738
# Processing... 1483 : P07741
# Processing... 1484 : P07766
# Processing... 1485 : P07814
# Processing... 1486 : P07858
# Processing... 1487 : P07900
# Processing... 1488 : P07902
# Processing... 1489 : P07910
# Processing... 1490 : P07911
# Processing... 1491 : P07919
# Processing... 1492 : P07942
# Processing... 1493 : P07947
# Processing... 1494 : P07948
# Processing... 1495 : P07951
# Processing... 1496 : P07954
# Processing... 1497 : P07992
# Processing... 1498 : P07996
# Processing... 1499 : P07998
# Processing... 1500 : P08047
# Processing... 1501 : P08048
# Processing... 1502 : P08069
# Processing... 1503 : P08118
# Processing... 1504 : P08123
# Processing... 1505 : P08133
# Processing... 1506 : P08134
# Processing... 1507 : P08174
# Processing... 1508 : P08185
# Processing... 1509 : P08195
# Processing... 1510 : P08236
# Processing... 1511 : P08237
# Processing... 1512 : P08238
# Processing... 1513 : P08240
# Processing... 1514 : P08243
# Processing... 1515 : P08246
# Processing... 1516 : P08253
# Processing... 1517 : P08254
# Processing... 1518 : P08263
# Processing... 1519 : P08294
# Processing... 1520 : P08311
# Processing... 1521 : P08397
# Processing... 1522 : P08473
# Processing... 1523 : P08493
# Processing... 1524 : P08514
# Processing... 1525 : P08519
# Processing... 1526 : P08559
# Processing... 1527 : P08567
# Processing... 1528 : P08571
# Processing... 1529 : P08572
# Processing... 1530 : P08574
# Processing... 1531 : P08575
# Processing... 1532 : P08579
# Processing... 1533 : P08581
# Processing... 1534 : P08590
# Processing... 1535 : P08603
# Processing... 1536 : P08621
# Processing... 1537 : P08631
# Processing... 1538 : P08637
# Processing... 1539 : P08648
# Processing... 1540 : P08651
# Processing... 1541 : P08670
# Processing... 1542 : P08684
# Processing... 1543 : P08697
# Processing... 1544 : P08708
# Processing... 1545 : P08709
# Processing... 1546 : P08727
# Processing... 1547 : P08729
# Processing... 1548 : P08754
# Processing... 1549 : P08758
# Processing... 1550 : P08779
# Processing... 1551 : P08842
# Processing... 1552 : P08865
# Processing... 1553 : P08910
# Processing... 1554 : P08962
# Processing... 1555 : P09001
# Processing... 1556 : P09012
# Processing... 1557 : P09016
# Processing... 1558 : P09104
# Processing... 1559 : P09105
# Processing... 1560 : P09110
# Processing... 1561 : P09132
# Processing... 1562 : P09211
# Processing... 1563 : P09234
# Processing... 1564 : P09237
# Processing... 1565 : P09238
# Processing... 1566 : P09326
# Processing... 1567 : P09341
# Processing... 1568 : P09382
# Processing... 1569 : P09417
# Processing... 1570 : P09429
# Processing... 1571 : P09455
# Processing... 1572 : P09466
# Processing... 1573 : P09467
# Processing... 1574 : P09471
# Processing... 1575 : P09486
# Processing... 1576 : P09488
# Processing... 1577 : P09493
# Processing... 1578 : P09496
# Processing... 1579 : P09497
# Processing... 1580 : P09525
# Processing... 1581 : P09543
# Processing... 1582 : P09601
# Processing... 1583 : P09619
# Processing... 1584 : P09622
# Processing... 1585 : P09651
# Processing... 1586 : P09661
# Processing... 1587 : P09668
# Processing... 1588 : P09669
# Processing... 1589 : P09758
# Processing... 1590 : P09769
# Processing... 1591 : P09871
# Processing... 1592 : P09874
# Processing... 1593 : P09884
# Processing... 1594 : P09913
# Processing... 1595 : P09914
# Processing... 1596 : P09917
# Processing... 1597 : P09936
# Processing... 1598 : P09958
# Processing... 1599 : P09960
# Processing... 1600 : P09972
# Processing... 1601 : P0C0L4
# Processing... 1602 : P0C0L5
# Processing... 1603 : P0C0S5
# Processing... 1604 : P0C1Z6
# Processing... 1605 : P0C2W1
# Processing... 1606 : P0C7P0
# Processing... 1607 : P0C7T5
# Processing... 1608 : P0C870
# Processing... 1609 : P0CAP1
# Processing... 1610 : P0CAP2
# Processing... 1611 : P0CG12
# Processing... 1612 : P0CG13
# Processing... 1613 : P0CG29
# Processing... 1614 : P0CJ79
# Processing... 1615 : P0DJ07
# Processing... 1616 : P0DJI8
# Processing... 1617 : P0DJI9
# Processing... 1618 : P0DMM9
# Processing... 1619 : P0DMU9
# Processing... 1620 : P0DMV8
# Processing... 1621 : P0DOY2
# Processing... 1622 : P0DP23
# Processing... 1623 : P0DP57
# Processing... 1624 : P0DPB6
# Processing... 1625 : P0DPD7
# Processing... 1626 : P0DPH7
# Processing... 1627 : P0DTE1
# Processing... 1628 : P0DTL6
# Processing... 1629 : P10109
# Processing... 1630 : P10114
# Processing... 1631 : P10124
# Processing... 1632 : P10145
# Processing... 1633 : P10153
# Processing... 1634 : P10155
# Processing... 1635 : P10176
# Processing... 1636 : P10253
# Processing... 1637 : P10275
# Processing... 1638 : P10301
# Processing... 1639 : P10321
# Processing... 1640 : P10398
# Processing... 1641 : P10412
# Processing... 1642 : P10451
# Processing... 1643 : P10515
# Processing... 1644 : P10586
# Processing... 1645 : P10588
# Processing... 1646 : P10599
# Processing... 1647 : P10606
# Processing... 1648 : P10619
# Processing... 1649 : P10620
# Processing... 1650 : P10635
# Processing... 1651 : P10636
# Processing... 1652 : P10643
# Processing... 1653 : P10644
# Processing... 1654 : P10721
# Processing... 1655 : P10746
# Processing... 1656 : P10768
# Processing... 1657 : P10809
# Processing... 1658 : P10909
# Processing... 1659 : P10915
# Processing... 1660 : P11021
# Processing... 1661 : P11047
# Processing... 1662 : P11049
# Processing... 1663 : P11086
# Processing... 1664 : P11117
# Processing... 1665 : P11137
# Processing... 1666 : P11142
# Processing... 1667 : P11166
# Processing... 1668 : P11169
# Processing... 1669 : P11171
# Processing... 1670 : P11172
# Processing... 1671 : P11177
# Processing... 1672 : P11182
# Processing... 1673 : P11215
# Processing... 1674 : P11216
# Processing... 1675 : P11217
# Processing... 1676 : P11226
# Processing... 1677 : P11233
# Processing... 1678 : P11234
# Processing... 1679 : P11274
# Processing... 1680 : P11277
# Processing... 1681 : P11279
# Processing... 1682 : P11308
# Processing... 1683 : P11310
# Processing... 1684 : P11387
# Processing... 1685 : P11388
# Processing... 1686 : P11413
# Processing... 1687 : P11441
# Processing... 1688 : P11474
# Processing... 1689 : P11498
# Processing... 1690 : P11532
# Processing... 1691 : P11586
# Processing... 1692 : P11678
# Processing... 1693 : P11717
# Processing... 1694 : P11766
# Processing... 1695 : P11802
# Processing... 1696 : P11908
# Processing... 1697 : P11940
# Processing... 1698 : P12004
# Processing... 1699 : P12074
# Processing... 1700 : P12081
# Processing... 1701 : P12107
# Processing... 1702 : P12109
# Processing... 1703 : P12110
# Processing... 1704 : P12111
# Processing... 1705 : P12235
# Processing... 1706 : P12236
# Processing... 1707 : P12259
# Processing... 1708 : P12268
# Processing... 1709 : P12270
# Processing... 1710 : P12273
# Processing... 1711 : P12277
# Processing... 1712 : P12314
# Processing... 1713 : P12318
# Processing... 1714 : P12429
# Processing... 1715 : P12532
# Processing... 1716 : P12544
# Processing... 1717 : P12645
# Processing... 1718 : P12694
# Processing... 1719 : P12724
# Processing... 1720 : P12814
# Processing... 1721 : P12821
# Processing... 1722 : P12830
# Processing... 1723 : P12931
# Processing... 1724 : P12955
# Processing... 1725 : P12956
# Processing... 1726 : P13010
# Processing... 1727 : P13051
# Processing... 1728 : P13056
# Processing... 1729 : P13073
# Processing... 1730 : P13196
# Processing... 1731 : P13224
# Processing... 1732 : P13284
# Processing... 1733 : P13473
# Processing... 1734 : P13489
# Processing... 1735 : P13498
# Processing... 1736 : P13521
# Processing... 1737 : P13584
# Processing... 1738 : P13591
# Processing... 1739 : P13611
# Processing... 1740 : P13612
# Processing... 1741 : P13631
# Processing... 1742 : P13639
# Processing... 1743 : P13645
# Processing... 1744 : P13646
# Processing... 1745 : P13647
# ...
# Processing... 8397 : Q9UJV9
# Processing... 8398 : Q9UJW0
# Processing... 8399 : Q9UJX2
# Processing... 8400 : Q9UJX3
# Processing... 8401 : Q9UJX4
# Processing... 8402 : Q9UJX5
# Processing... 8403 : Q9UJX6
# Processing... 8404 : Q9UJY1
# Processing... 8405 : Q9UJY4
# Processing... 8406 : Q9UJY5
# Processing... 8407 : Q9UJZ1
# Processing... 8408 : Q9UK13
# Processing... 8409 : Q9UK22
# Processing... 8410 : Q9UK23
# Processing... 8411 : Q9UK32
# Processing... 8412 : Q9UK41
# Processing... 8413 : Q9UK45
# Processing... 8414 : Q9UK53
# Processing... 8415 : Q9UK55
# Processing... 8416 : Q9UK58
# Processing... 8417 : Q9UK59
# Processing... 8418 : Q9UK61
# Processing... 8419 : Q9UK73
# Processing... 8420 : Q9UK76
# Processing... 8421 : Q9UK99
# Processing... 8422 : Q9UKA4
# Processing... 8423 : Q9UKA8
# Processing... 8424 : Q9UKA9
# Processing... 8425 : Q9UKB1
# Processing... 8426 : Q9UKD1
# Processing... 8427 : Q9UKD2
# Processing... 8428 : Q9UKE5
# Processing... 8429 : Q9UKF6
# Processing... 8430 : Q9UKF7
# Processing... 8431 : Q9UKG1
# Processing... 8432 : Q9UKG9
# Processing... 8433 : Q9UKI8
# Processing... 8434 : Q9UKJ3
# Processing... 8435 : Q9UKK3
# Processing... 8436 : Q9UKK6
# Processing... 8437 : Q9UKK9
# Processing... 8438 : Q9UKL0
# Processing... 8439 : Q9UKL6
# Processing... 8440 : Q9UKM7
# Processing... 8441 : Q9UKM9
# Processing... 8442 : Q9UKN8
# Processing... 8443 : Q9UKQ2
# Processing... 8444 : Q9UKR5
# Processing... 8445 : Q9UKS6
# Processing... 8446 : Q9UKS7
# Processing... 8447 : Q9UKT5
# Processing... 8448 : Q9UKT8
# Processing... 8449 : Q9UKT9
# Processing... 8450 : Q9UKU7
# Processing... 8451 : Q9UKU9
# Processing... 8452 : Q9UKV3
# Processing... 8453 : Q9UKV5
# Processing... 8454 : Q9UKV8
# Processing... 8455 : Q9UKW4
# Processing... 8456 : Q9UKX2
# Processing... 8457 : Q9UKX7
# Processing... 8458 : Q9UKY1
# Processing... 8459 : Q9UKY3
# Processing... 8460 : Q9UKY7
# Processing... 8461 : Q9UKZ1
# Processing... 8462 : Q9UL03
# Processing... 8463 : Q9UL15
# Processing... 8464 : Q9UL16
# Processing... 8465 : Q9UL18
# Processing... 8466 : Q9UL25
# Processing... 8467 : Q9UL26
# Processing... 8468 : Q9UL33
# Processing... 8469 : Q9UL40
# Processing... 8470 : Q9UL45
# Processing... 8471 : Q9UL46
# Processing... 8472 : Q9UL52
# Processing... 8473 : Q9UL54
# Processing... 8474 : Q9UL63
# Processing... 8475 : Q9ULA0
# Processing... 8476 : Q9ULC3
# Processing... 8477 : Q9ULC4
# Processing... 8478 : Q9ULC5
# Processing... 8479 : Q9ULC6
# Processing... 8480 : Q9ULD0
# Processing... 8481 : Q9ULD2
# Processing... 8482 : Q9ULD4
# Processing... 8483 : Q9ULF5
# Processing... 8484 : Q9ULH0
# Processing... 8485 : Q9ULH1
# Processing... 8486 : Q9ULH7
# Processing... 8487 : Q9ULI0
# Processing... 8488 : Q9ULJ1
# Processing... 8489 : Q9ULJ3
# Processing... 8490 : Q9ULJ6
# Processing... 8491 : Q9ULJ7
# Processing... 8492 : Q9ULJ8
# Processing... 8493 : Q9ULK4
# Processing... 8494 : Q9ULK5
# Processing... 8495 : Q9ULL1
# Processing... 8496 : Q9ULL4
# Processing... 8497 : Q9ULL5
# Processing... 8498 : Q9ULL8
# Processing... 8499 : Q9ULM3
# Processing... 8500 : Q9ULP0
# Processing... 8501 : Q9ULP9
# Processing... 8502 : Q9ULQ1
# Processing... 8503 : Q9ULR0
# Processing... 8504 : Q9ULR3
# Processing... 8505 : Q9ULS5
# Processing... 8506 : Q9ULT8
# Processing... 8507 : Q9ULU4
# Processing... 8508 : Q9ULV0
# Processing... 8509 : Q9ULV3
# Processing... 8510 : Q9ULV4
# Processing... 8511 : Q9ULV8
# Processing... 8512 : Q9ULW0
# Processing... 8513 : Q9ULW3
# Processing... 8514 : Q9ULW8
# Processing... 8515 : Q9ULX3
# Processing... 8516 : Q9ULX6
# Processing... 8517 : Q9ULX9
# Processing... 8518 : Q9ULZ3
# Processing... 8519 : Q9UM00
# Processing... 8520 : Q9UM07
# Processing... 8521 : Q9UM13
# Processing... 8522 : Q9UM21
# Processing... 8523 : Q9UM47
# Processing... 8524 : Q9UM54
# Processing... 8525 : Q9UMD9
# Processing... 8526 : Q9UMR2
# Processing... 8527 : Q9UMR5
# Processing... 8528 : Q9UMS0
# Processing... 8529 : Q9UMS4
# Processing... 8530 : Q9UMS6
# Processing... 8531 : Q9UMX0
# Processing... 8532 : Q9UMX1
# Processing... 8533 : Q9UMX3
# Processing... 8534 : Q9UMX5
# Processing... 8535 : Q9UMY1
# Processing... 8536 : Q9UMY4
# Processing... 8537 : Q9UMZ2
# Processing... 8538 : Q9UN19
# Processing... 8539 : Q9UN36
# Processing... 8540 : Q9UN37
# Processing... 8541 : Q9UN70
# Processing... 8542 : Q9UN76
# Processing... 8543 : Q9UN81
# Processing... 8544 : Q9UN86
# Processing... 8545 : Q9UNA1
# Processing... 8546 : Q9UNA4
# Processing... 8547 : Q9UNE7
# Processing... 8548 : Q9UNF0
# Processing... 8549 : Q9UNF1
# Processing... 8550 : Q9UNH6
# Processing... 8551 : Q9UNH7
# Processing... 8552 : Q9UNI6
# Processing... 8553 : Q9UNK0
# Processing... 8554 : Q9UNL2
# Processing... 8555 : Q9UNL4
# Processing... 8556 : Q9UNM6
# Processing... 8557 : Q9UNN5
# Processing... 8558 : Q9UNN8
# Processing... 8559 : Q9UNP4
# Processing... 8560 : Q9UNP9
# Processing... 8561 : Q9UNQ0
# Processing... 8562 : Q9UNQ2
# Processing... 8563 : Q9UNS2
# Processing... 8564 : Q9UNW1
# Processing... 8565 : Q9UNW9
# Processing... 8566 : Q9UNX3
# Processing... 8567 : Q9UNX4
# Processing... 8568 : Q9UNY4
# Processing... 8569 : Q9UNZ2
# Processing... 8570 : Q9UNZ5
# Processing... 8571 : Q9UP38
# Processing... 8572 : Q9UP83
# Processing... 8573 : Q9UP95
# Processing... 8574 : Q9UPM8
# Processing... 8575 : Q9UPN3
# Processing... 8576 : Q9UPN4
# Processing... 8577 : Q9UPN6
# Processing... 8578 : Q9UPN7
# Processing... 8579 : Q9UPN9
# Processing... 8580 : Q9UPP1
# Processing... 8581 : Q9UPQ0
# Processing... 8582 : Q9UPQ9
# Processing... 8583 : Q9UPR3
# Processing... 8584 : Q9UPS6
# Processing... 8585 : Q9UPT5
# Processing... 8586 : Q9UPT6
# Processing... 8587 : Q9UPT8
# Processing... 8588 : Q9UPT9
# Processing... 8589 : Q9UPU5
# Processing... 8590 : Q9UPU7
# Processing... 8591 : Q9UPW0
# Processing... 8592 : Q9UPX8
# Processing... 8593 : Q9UPY3
# Processing... 8594 : Q9UPY5
# Processing... 8595 : Q9UPY6
# Processing... 8596 : Q9UPY8
# Processing... 8597 : Q9UPZ3
# Processing... 8598 : Q9UQ03
# Processing... 8599 : Q9UQ13
# Processing... 8600 : Q9UQ16
# Processing... 8601 : Q9UQ35
# Processing... 8602 : Q9UQ49
# Processing... 8603 : Q9UQ53
# Processing... 8604 : Q9UQ80
# Processing... 8605 : Q9UQ90
# Processing... 8606 : Q9UQB8
# Processing... 8607 : Q9UQC9
# Processing... 8608 : Q9UQE7
# Processing... 8609 : Q9UQL6
# Processing... 8610 : Q9UQN3
# Processing... 8611 : Q9UQR1
# Processing... 8612 : Q9Y217
# Processing... 8613 : Q9Y221
# Processing... 8614 : Q9Y223
# Processing... 8615 : Q9Y224
# Processing... 8616 : Q9Y227
# Processing... 8617 : Q9Y228
# Processing... 8618 : Q9Y230
# Processing... 8619 : Q9Y232
# Processing... 8620 : Q9Y234
# Processing... 8621 : Q9Y237
# Processing... 8622 : Q9Y240
# Processing... 8623 : Q9Y241
# Processing... 8624 : Q9Y243
# Processing... 8625 : Q9Y244
# Processing... 8626 : Q9Y250
# Processing... 8627 : Q9Y257
# Processing... 8628 : Q9Y259
# Processing... 8629 : Q9Y262
# Processing... 8630 : Q9Y263
# Processing... 8631 : Q9Y265
# Processing... 8632 : Q9Y266
# Processing... 8633 : Q9Y276
# Processing... 8634 : Q9Y277
# Processing... 8635 : Q9Y281
# Processing... 8636 : Q9Y282
# Processing... 8637 : Q9Y285
# Processing... 8638 : Q9Y287
# Processing... 8639 : Q9Y289
# Processing... 8640 : Q9Y291
# Processing... 8641 : Q9Y294
# Processing... 8642 : Q9Y295
# Processing... 8643 : Q9Y296
# Processing... 8644 : Q9Y2A7
# Processing... 8645 : Q9Y2A9
# Processing... 8646 : Q9Y2B0
# Processing... 8647 : Q9Y2B2
# Processing... 8648 : Q9Y2B9
# Processing... 8649 : Q9Y2C2
# Processing... 8650 : Q9Y2C4
# Processing... 8651 : Q9Y2D2
# Processing... 8652 : Q9Y2D4
# Processing... 8653 : Q9Y2D5
# Processing... 8654 : Q9Y2D9
# Processing... 8655 : Q9Y2E5
# Processing... 8656 : Q9Y2G2
# Processing... 8657 : Q9Y2G3
# Processing... 8658 : Q9Y2G5
# Processing... 8659 : Q9Y2G8
# Processing... 8660 : Q9Y2H0
# Processing... 8661 : Q9Y2H1
# Processing... 8662 : Q9Y2H2
# Processing... 8663 : Q9Y2H5
# Processing... 8664 : Q9Y2H6
# Processing... 8665 : Q9Y2I1
# Processing... 8666 : Q9Y2I8
# Processing... 8667 : Q9Y2I9
# Processing... 8668 : Q9Y2J2
# Processing... 8669 : Q9Y2J8
# Processing... 8670 : Q9Y2K1
# Processing... 8671 : Q9Y2K2
# Processing... 8672 : Q9Y2K6
# Processing... 8673 : Q9Y2K7
# Processing... 8674 : Q9Y2L1
# Processing... 8675 : Q9Y2L5
# Processing... 8676 : Q9Y2L9
# Processing... 8677 : Q9Y2P4
# Processing... 8678 : Q9Y2P8
# Processing... 8679 : Q9Y2Q0
# Processing... 8680 : Q9Y2Q3
# Processing... 8681 : Q9Y2Q5
# Processing... 8682 : Q9Y2Q9
# Processing... 8683 : Q9Y2R0
# Processing... 8684 : Q9Y2R4
# Processing... 8685 : Q9Y2R5
# Processing... 8686 : Q9Y2R9
# Processing... 8687 : Q9Y2S2
# Processing... 8688 : Q9Y2S6
# Processing... 8689 : Q9Y2S7
# Processing... 8690 : Q9Y2T2
# Processing... 8691 : Q9Y2T3
# Processing... 8692 : Q9Y2U5
# Processing... 8693 : Q9Y2U8
# Processing... 8694 : Q9Y2U9
# Processing... 8695 : Q9Y2V0
# Processing... 8696 : Q9Y2V2
# Processing... 8697 : Q9Y2V7
# Processing... 8698 : Q9Y2W1
# Processing... 8699 : Q9Y2W2
# Processing... 8700 : Q9Y2W6
# Processing... 8701 : Q9Y2X0
# Processing... 8702 : Q9Y2X3
# Processing... 8703 : Q9Y2X7
# Processing... 8704 : Q9Y2X9
# Processing... 8705 : Q9Y2Y0
# Processing... 8706 : Q9Y2Y1
# Processing... 8707 : Q9Y2Y8
# Processing... 8708 : Q9Y2Z0
# Processing... 8709 : Q9Y2Z2
# Processing... 8710 : Q9Y2Z4
# Processing... 8711 : Q9Y2Z9
# Processing... 8712 : Q9Y303
# Processing... 8713 : Q9Y305
# Processing... 8714 : Q9Y312
# Processing... 8715 : Q9Y314
# Processing... 8716 : Q9Y315
# Processing... 8717 : Q9Y316
# Processing... 8718 : Q9Y320
# Processing... 8719 : Q9Y324
# Processing... 8720 : Q9Y333
# Processing... 8721 : Q9Y342
# Processing... 8722 : Q9Y343
# Processing... 8723 : Q9Y365
# Processing... 8724 : Q9Y366
# Processing... 8725 : Q9Y371
# Processing... 8726 : Q9Y375
# Processing... 8727 : Q9Y376
# Processing... 8728 : Q9Y383
# Processing... 8729 : Q9Y385
# Processing... 8730 : Q9Y388
# Processing... 8731 : Q9Y394
# Processing... 8732 : Q9Y399
# Processing... 8733 : Q9Y3A2
# Processing... 8734 : Q9Y3A3
# Processing... 8735 : Q9Y3A4
# Processing... 8736 : Q9Y3A5
# Processing... 8737 : Q9Y3A6
# Processing... 8738 : Q9Y3B2
# Processing... 8739 : Q9Y3B3
# Processing... 8740 : Q9Y3B4
# Processing... 8741 : Q9Y3B6
# Processing... 8742 : Q9Y3B7
# Processing... 8743 : Q9Y3B8
# Processing... 8744 : Q9Y3B9
# Processing... 8745 : Q9Y3C0
# Processing... 8746 : Q9Y3C1
# Processing... 8747 : Q9Y3C4
# Processing... 8748 : Q9Y3C5
# Processing... 8749 : Q9Y3C6
# Processing... 8750 : Q9Y3C7
# Processing... 8751 : Q9Y3C8
# Processing... 8752 : Q9Y3D0
# Processing... 8753 : Q9Y3D2
# Processing... 8754 : Q9Y3D3
# Processing... 8755 : Q9Y3D5
# Processing... 8756 : Q9Y3D6
# Processing... 8757 : Q9Y3D7
# Processing... 8758 : Q9Y3D8
# Processing... 8759 : Q9Y3D9
# Processing... 8760 : Q9Y3E0
# Processing... 8761 : Q9Y3E1
# Processing... 8762 : Q9Y3E2
# Processing... 8763 : Q9Y3E5
# Processing... 8764 : Q9Y3E7
# Processing... 8765 : Q9Y3F4
# Processing... 8766 : Q9Y3I0
# Processing... 8767 : Q9Y3I1
# Processing... 8768 : Q9Y3L3
# Processing... 8769 : Q9Y3L5
# Processing... 8770 : Q9Y3M8
# Processing... 8771 : Q9Y3P4
# Processing... 8772 : Q9Y3P9
# Processing... 8773 : Q9Y3Q3
# Processing... 8774 : Q9Y3Q8
# Processing... 8775 : Q9Y3R5
# Processing... 8776 : Q9Y3S1
# Processing... 8777 : Q9Y3S2
# Processing... 8778 : Q9Y3T6
# Processing... 8779 : Q9Y3T9
# Processing... 8780 : Q9Y3U8
# Processing... 8781 : Q9Y3X0
# Processing... 8782 : Q9Y3Y2
# Processing... 8783 : Q9Y3Z3
# Processing... 8784 : Q9Y426
# Processing... 8785 : Q9Y446
# Processing... 8786 : Q9Y450
# Processing... 8787 : Q9Y478
# Processing... 8788 : Q9Y483
# Processing... 8789 : Q9Y484
# Processing... 8790 : Q9Y485
# Processing... 8791 : Q9Y487
# Processing... 8792 : Q9Y490
# Processing... 8793 : Q9Y496
# Processing... 8794 : Q9Y4A5
# Processing... 8795 : Q9Y4B4
# Processing... 8796 : Q9Y4B5
# Processing... 8797 : Q9Y4B6
# Processing... 8798 : Q9Y4C1
# Processing... 8799 : Q9Y4C2
# Processing... 8800 : Q9Y4C8
# Processing... 8801 : Q9Y4D1
# Processing... 8802 : Q9Y4D8
# Processing... 8803 : Q9Y4E1
# Processing... 8804 : Q9Y4E5
# Processing... 8805 : Q9Y4E6
# Processing... 8806 : Q9Y4E8
# Processing... 8807 : Q9Y4F1
# Processing... 8808 : Q9Y4F3
# Processing... 8809 : Q9Y4F5
# Processing... 8810 : Q9Y4G2
# Processing... 8811 : Q9Y4G6
# Processing... 8812 : Q9Y4G8
# Processing... 8813 : Q9Y4H2
# Processing... 8814 : Q9Y4H4
# Processing... 8815 : Q9Y4I1
# Processing... 8816 : Q9Y4J8
# Processing... 8817 : Q9Y4K0
# Processing... 8818 : Q9Y4K1
# Processing... 8819 : Q9Y4K3
# Processing... 8820 : Q9Y4K4
# Processing... 8821 : Q9Y4L1
# Processing... 8822 : Q9Y4P1
# Processing... 8823 : Q9Y4P3
# Processing... 8824 : Q9Y4P8
# Processing... 8825 : Q9Y4R8
# Processing... 8826 : Q9Y4W2
# Processing... 8827 : Q9Y4W6
# Processing... 8828 : Q9Y4X5
# Processing... 8829 : Q9Y4Z0
# Processing... 8830 : Q9Y508
# Processing... 8831 : Q9Y512
# Processing... 8832 : Q9Y520
# Processing... 8833 : Q9Y530
# Processing... 8834 : Q9Y535
# Processing... 8835 : Q9Y547
# Processing... 8836 : Q9Y548
# Processing... 8837 : Q9Y570
# Processing... 8838 : Q9Y572
# Processing... 8839 : Q9Y580
# Processing... 8840 : Q9Y584
# Processing... 8841 : Q9Y597
# Processing... 8842 : Q9Y5A7
# Processing... 8843 : Q9Y5A9
# Processing... 8844 : Q9Y5B0
# Processing... 8845 : Q9Y5B6
# Processing... 8846 : Q9Y5B8
# Processing... 8847 : Q9Y5B9
# Processing... 8848 : Q9Y5J1
# Processing... 8849 : Q9Y5J5
# Processing... 8850 : Q9Y5J6
# Processing... 8851 : Q9Y5J7
# Processing... 8852 : Q9Y5J9
# Processing... 8853 : Q9Y5K5
# Processing... 8854 : Q9Y5K6
# Processing... 8855 : Q9Y5K8
# Processing... 8856 : Q9Y5L0
# Processing... 8857 : Q9Y5L3
# Processing... 8858 : Q9Y5L4
# Processing... 8859 : Q9Y5M8
# Processing... 8860 : Q9Y5N5
# Processing... 8861 : Q9Y5P4
# Processing... 8862 : Q9Y5P6
# Processing... 8863 : Q9Y5Q8
# Processing... 8864 : Q9Y5Q9
# Processing... 8865 : Q9Y5R4
# Processing... 8866 : Q9Y5R8
# Processing... 8867 : Q9Y5S1
# Processing... 8868 : Q9Y5S2
# Processing... 8869 : Q9Y5S9
# Processing... 8870 : Q9Y5T5
# Processing... 8871 : Q9Y5U2
# Processing... 8872 : Q9Y5U8
# Processing... 8873 : Q9Y5U9
# Processing... 8874 : Q9Y5V0
# Processing... 8875 : Q9Y5V3
# Processing... 8876 : Q9Y5W7
# Processing... 8877 : Q9Y5W8
# Processing... 8878 : Q9Y5W9
# Processing... 8879 : Q9Y5X1
# Processing... 8880 : Q9Y5X2
# Processing... 8881 : Q9Y5X3
# Processing... 8882 : Q9Y5Y0
# Processing... 8883 : Q9Y5Y2
# Processing... 8884 : Q9Y5Y5
# Processing... 8885 : Q9Y5Y6
# Processing... 8886 : Q9Y5Y7
# Processing... 8887 : Q9Y5Z4
# Processing... 8888 : Q9Y5Z9
# Processing... 8889 : Q9Y605
# Processing... 8890 : Q9Y606
# Processing... 8891 : Q9Y608
# Processing... 8892 : Q9Y613
# Processing... 8893 : Q9Y617
# Processing... 8894 : Q9Y618
# Processing... 8895 : Q9Y619
# Processing... 8896 : Q9Y624
# Processing... 8897 : Q9Y625
# Processing... 8898 : Q9Y639
# Processing... 8899 : Q9Y646
# Processing... 8900 : Q9Y653
# Processing... 8901 : Q9Y657
# Processing... 8902 : Q9Y664
# Processing... 8903 : Q9Y666
# Processing... 8904 : Q9Y672
# Processing... 8905 : Q9Y673
# Processing... 8906 : Q9Y676
# Processing... 8907 : Q9Y678
# Processing... 8908 : Q9Y679
# Processing... 8909 : Q9Y680
# Processing... 8910 : Q9Y692
# Processing... 8911 : Q9Y696
# Processing... 8912 : Q9Y697
# Processing... 8913 : Q9Y6A4
# Processing... 8914 : Q9Y6A5
# Processing... 8915 : Q9Y6A9
# Processing... 8916 : Q9Y6B6
# Processing... 8917 : Q9Y6B7
# Processing... 8918 : Q9Y6C2
# Processing... 8919 : Q9Y6C9
# Processing... 8920 : Q9Y6D5
# Processing... 8921 : Q9Y6D6
# Processing... 8922 : Q9Y6D9
# Processing... 8923 : Q9Y6E0
# Processing... 8924 : Q9Y6E2
# Processing... 8925 : Q9Y6F6
# Processing... 8926 : Q9Y6G3
# Processing... 8927 : Q9Y6G5
# Processing... 8928 : Q9Y6G9
# Processing... 8929 : Q9Y6H1
# Processing... 8930 : Q9Y6I3
# Processing... 8931 : Q9Y6I4
# Processing... 8932 : Q9Y6I8
# Processing... 8933 : Q9Y6I9
# Processing... 8934 : Q9Y6J0
# Processing... 8935 : Q9Y6J9
# Processing... 8936 : Q9Y6K0
# Processing... 8937 : Q9Y6K1
# Processing... 8938 : Q9Y6K5
# Processing... 8939 : Q9Y6K9
# Processing... 8940 : Q9Y6M1
# Processing... 8941 : Q9Y6M4
# Processing... 8942 : Q9Y6M5
# Processing... 8943 : Q9Y6M7
# Processing... 8944 : Q9Y6M9
# Processing... 8945 : Q9Y6N1
# Processing... 8946 : Q9Y6N5
# Processing... 8947 : Q9Y6N6
# Processing... 8948 : Q9Y6N7
# Processing... 8949 : Q9Y6Q5
# Processing... 8950 : Q9Y6Q9
# Processing... 8951 : Q9Y6R0
# Processing... 8952 : Q9Y6R1
# Processing... 8953 : Q9Y6R4
# Processing... 8954 : Q9Y6R7
# Processing... 8955 : Q9Y6R9
# Processing... 8956 : Q9Y6U3
# Processing... 8957 : Q9Y6V7
# Processing... 8958 : Q9Y6W3
# Processing... 8959 : Q9Y6W5
# Processing... 8960 : Q9Y6X2
# Processing... 8961 : Q9Y6X3
# Processing... 8962 : Q9Y6X4
# Processing... 8963 : Q9Y6X5
# Processing... 8964 : Q9Y6X8
# Processing... 8965 : Q9Y6X9
# Processing... 8966 : Q9Y6Y0
# Processing... 8967 : Q9Y6Y8

# %%
dictn = json_data["results"][34]["to"]

if dictn.get('proteinDescription') == None:
    print(dictn.get('inactiveReason'))

#pr_name = json_data["results"][34]["to"]["proteinDescription"]["submissionNames"][0]["fullName"]["value"]
# Out:
# {'inactiveReasonType': 'DELETED'}

# %%
# Recommended Name (5, )
n_try = 34

try:
    pr_name = json_data['results'][n_try]['to']['proteinDescription']['recommendedName']['fullName']['value']
except:
    pr_name = json_data['results'][n_try]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']

print(pr_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       4 try:
# ----> 5     pr_name = json_data['results'][n_try]['to']['proteinDescription']['recommendedName']['fullName']['value']
#       6 except:
#
# KeyError: 'proteinDescription'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 7
#       5     pr_name = json_data['results'][n_try]['to']['proteinDescription']['recommendedName']['fullName']['value']
#       6 except:
# ----> 7     pr_name = json_data['results'][n_try]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']
#       9 print(pr_name)
#
# KeyError: 'proteinDescription'

# %%
# Alternative Name (4, )
pr_name = json_data['results'][4]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
print(pr_name)
# Out:
# NADH dehydrogenase [ubiquinone] 1 alpha subcomplex assembly factor 1

# %%
# Protein Names
row_num = 7
rec_name = json_data['results'][row_num]['to']['proteinDescription']['recommendedName']['fullName']['value']
#alt_name = json_data['results'][row_num]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
sub_name = json_data['results'][row_num]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']

print(rec_name)
#print(alt_name)
print(sub_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       2 row_num = 7
#       3 #rec_name = json_data['results'][row_num]['to']['proteinDescription']['recommendedName']['fullName']['value']
# ----> 4 alt_name = json_data['results'][row_num]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
#       5 sub_name = json_data['results'][row_num]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']
#       7 #print(rec_name)
#
# KeyError: 'alternativeNames'

# %%
data = json_data['results'][1499]['to']['genes']
# KeyError: 'genes'

print(data)
# empty
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 data = json_data['results'][1499]['to']['genes']
#       2 #[{'geneName': {'value': 'Psmd4'}, 'synonyms': [{'value': 'Mcb1'}]}]
#       3
#       4 #data = json_data['results'][99]['to']['genes'][0]
#    (...)
#      12
#      13 #data = json_data['results'][99]['to']['genes'][0]['geneName']['value']
#      14 print(data)
#
# KeyError: 'genes'

# %%
#data = json_data['results'][99]['to']['genes']
#[{'geneName': {'value': 'Psmd4'}, 'synonyms': [{'value': 'Mcb1'}]}]

#data = json_data['results'][99]['to']['genes'][0]
#{'geneName': {'value': 'Psmd4'}, 'synonyms': [{'value': 'Mcb1'}]}

#data = json_data['results'][99]['to']['genes'][0]['geneName']
#{'value': 'Psmd4'}

#data = json_data['results'][99]['to']['genes'][0]['synonyms'].__len__()
#1

data = json_data['results'][99]['to']['genes'][0]['geneName']['value']
print(data)
#Psmd4
# Out:
# Psmd4

# %%
#data = json_data['results'][295]['to']['genes']
#[{'geneName': {'value': 'Gsta1'}, 'synonyms': [{'value': 'Gsta'}, {'value': 'Gstya'}]}]

#data = json_data['results'][295]['to']['genes'][0]['synonyms']
#[{'value': 'Gsta'}, {'value': 'Gstya'}]

#data = json_data['results'][99]['to']['genes'][0]['synonyms'].__len__()
#2

#data = json_data['results'][295]['to']['genes'][0]['synonyms'][0]
#{'value': 'Gsta'}

synonyms = json_data['results'][295]['to']['genes'][0]['synonyms']

for num in range(synonyms.__len__()):
    print(synonyms[num]['value'])

# Gene name must be one
# Synonym 0 or more.
# Out:
# Gsta
# Gstya

# %%
"""
# json_data['results'][int]['from']
# json_data['results'][int]['to']['proteinDescription']['recommendedName']['fullName']['value']
# json_data['results'][int]['to']['proteinDescription']['alternativeNames'][0]['fullName']['value']
# json_data['results'][int]['to']['proteinDescription']['submissionNames'][0]['fullName']['value']

Uniprot .json file structure by keys

results
    from
        Uniprot Accession ID
    to
        'entryType' : 'UniProtKB reviewed (Swiss-Prot)' OR 'UniProtKB unreviewed (TrEMBL)'
        'primaryAccession' : (Primary Accession ID)
        'uniProtkbId' : UniprotKB_MOUSE
        'entryAudit'
        'annotationScore'
        'organism'
            'scientificName'
            'commonName'
            'taxonId'
            'evidences'
                ['evidenceCode', 'source', 'id']
            'lineage'
        'proteinExistence'
        'proteinDescription'
            'recommendedName'
                'fullName'
                    'evidences'
                    ['evidenceCode', 'source', 'id'],
                    'value' <-- ***
            'alternativeNames'
            [
            'fullName'
                'evidences'
                ['evidenceCode', 'source', 'id'],
                'value' <-- ***
            ]
            'submissionNames'
            [
            'fullName'
                'evidences'
                ['evidenceCode', 'source', 'id']
                'value' <-- ***
            ]
        'genes'
        [
        'geneName'
            'evidences'
            ['evidenceCode', 'source', 'id'],
            'value'
        ]
        'features'
        'keywords'
        'references' <-- # of N from ['references'].__len__() 
        [
        'citation'
            'id'
            'citationType'
            'authors'
            'citationCrossReferences'
            'title'
            'publicationDate'
            'journal'
            'firstPage'
            'lastPage'
            'volume'
        'referencePositions'
        'referencecomments'
        'evidences'
        ]
        'uniProtKBCrossReferences'
        'sequence'
            'value' <-- ***
            'length'
            'molWeight'
            'crc64'
            'md5'
        'extraAttributes'
"""
# Out:
# 17242355
# 18630941
# 19144319
# 19468303
# 21183079
# CI-20IMGCHMHIQ52

# %%
num_sublist = json_data['results'][1]['to']['references'].__len__()

for i in range(num_sublist):
    keynames = json_data['results'][1]['to']['references'][i]['citation']
    PMID = keynames['id']
    print(PMID)

pr_names = json_data['results'][1]['to']['references'][0]['citation']
#print(pr_names)
# Out:
# 17242355
# 18630941
# 19144319
# 19468303
# 21183079
# CI-20IMGCHMHIQ52
